# %% [markdown]
# ### Импорты

# %%
import os

import pandas as pd
import re
import time
from tqdm.notebook import tqdm
from datetime import date, datetime

import json

# %%
channels_info = pd.read_csv('../../data/telegram/channels.csv')
channels_info.head()
# Out:
#    channel_id                 name  subscribers  \
# 0           0  Тинькофф Инвестиции       670825
# 1           1     Альфа-Инвестиции       415942
# 2           2       Мои Инвестиции       286117
# 3           3             bitkogan       284405
# 4           4       СберИнвестиции       232751
#
#                                    link  \
# 0  https://t.me/tinkoff_invest_official
# 1         https://t.me/alfa_investments
# 2           https://t.me/omyinvestments
# 3                 https://t.me/bitkogan
# 4          https://t.me/SberInvestments
#
#                                          description          create_date  \
# 0                        Официальный канал Тинькофф.  2019-09-04 15:50:32
# 1  Официальный канал Альфа-Инвестиций с инвестиде...  2021-06-18 14:04:01
# 2  Инвестидеи, обзоры рынка и многое другое от лу...  2019-09-12 12:53:25
# 3                     Авторский канал Евгения Когана  2018-01-14 14:46:07
# 4  Канал СберИнвестиции, в котором мы рассказывае...  2020-07-24 16:15:43
#
#    message_cnt
# 0         44.0
# 1        384.0
# 2         11.0
# 3       1777.0
# 4        419.0

# %%
path = '../../data/telegram/messages.csv'
messages_df = pd.read_csv(path)
messages_df.head()
# Out:
#    message_id  channel_id  tg_message_id                 date  \
# 0         552           1           4332  2023-11-02 12:31:28
# 1         551           1           4333  2023-11-02 14:33:01
# 2         550           1           4337  2023-11-02 15:56:40
# 3         549           1           4338  2023-11-03 07:59:27
# 4         548           1           4339  2023-11-03 10:44:50
#
#                                                 text   views  forwards  \
# 0  Центробанку, скорее всего, придётся поднять ст...  110394       401
# 1  Сбербанк продолжает рост: результаты по междун...  110495        76
# 2  Плохие новости сегодня вечером. СПБ Биржа попа...  125490       469
# 3  📉 Вчера на российском рынке акций прошли распр...  323274        41
# 4  У Норникеля сразу две приятные новости: компан...  315471       240
#
#                                            reactions
# 0  [{'_': 'ReactionCount', 'reaction': '👍', 'coun...
# 1  [{'_': 'ReactionCount', 'reaction': '👍', 'coun...
# 2  [{'_': 'ReactionCount', 'reaction': '😢', 'coun...
# 3  [{'_': 'ReactionCount', 'reaction': '👍', 'coun...
# 4  [{'_': 'ReactionCount', 'reaction': '👍', 'coun...
