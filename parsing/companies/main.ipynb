# %%
import json

# %%
d = {
    'crystal' : {
        'ticker' : 'KLVZ',
        'names'  : ['Кристалл', 'ЗАО Кристалл', 'ПАО Кристалл', 'ОАО Кристалл']
        }, 
    
    'diasoft' : {
        'ticker' : 'DIAS',
        'names'  : ['Диасофт', 'Diasoft', 'Диасофт Финансовые Технологии', 'Diasoft Financial Technologies']
        }, 
    
    'delimobil' : {
        'ticker' : 'DELI',
        'names'  : ['Делимобиль', 'Delimobil', 'Каршеринг Делимобиль', 'Delimobile', 'Делимобил']
            }, 
    
    'mosgorlombard' : {
        'ticker' : 'MGKL',
        'names'  : ['Мосгорломбард', 'ГУП Мосгорломбард', 'Государственное учреждение Мосгорломбард', 'Московский городской ломбард']
        },

    'sovkombank' : {
        'ticker' : 'SVCB',
        'names'  : ['Совкомбанк', 'ПАО Совкомбанк', 'Совкомбанк ПАО', 'ОАО Совкомбанк']
        }, 

    'ugk' : {
        'ticker' : 'UGLD',
        'names'  : ['УГК', 'Управляющая Горнорудная Компания', 'Управляющая Компания УГК']
        },
    
    'eurotrans' : {
        'ticker' : 'EUTR',
        'names'  : ['Евротранс', 'Eurotrans', 'Евротранс Логистик', 'Eurotrans Logistics']
        },
    
    'henderson' : {
        'ticker' : 'HNFG',
        'names'  : ['Henderson', 'Хендерсон', 'Henderson Russia', 'Хендерсон Россия']
        },
    
    'astra' : {
        'ticker' : 'ASTR',
        'names'  : ['Astra Group', 'Астра Груп', 'Группа Астра', 'Astra Group Incorporated', 'Астра Групп Инкорпорейтед', 'астр']
        },
    
    'carmoney' : {
        'ticker' : 'CARM',
        'names'  : ['CarMoney', 'КарМани', 'КарМани Займ', 'CarMoney Займы', 'КарМани Финансы']
        }, 
    
    'genetico' : {
        'ticker' : 'GECO',
        'names'  : ['Генетико', 'Genetico', 'Компания "Генетико"', 'ООО "Генетико"', 'генетик']
        },
    
    'whoosh' : {
        'ticker' : 'WUSH',
        'names'  : ['Whoosh', 'Вуш', 'Whoosh скутершеринг', 'Вуш скутершеринг']
        },
    
    'positive' : {
        'ticker' : 'POSI',
        'names'  : ['Positive Group', 'Позитив Групп', 'Группа Позитив', 'Positive Group LLC', 'ООО "Позитив Групп"']
        },
    
    'spb' : {
        'ticker' : 'SPBE',
        'names'  : ['СПБ Биржа', 'Санкт-Петербургская Биржа', 'СПб Биржа', 'SPB Exchange', 'Saint Petersburg Exchange', 'спб бирж']
        },
    
    'cian' : {
        'ticker' : 'CIAN',
        'names'  : ['ЦИАН', 'CIAN', 'Центр Информации Активов Недвижимости', 'ЦИАН Групп', 'CIAN Group']
        },
    
    'renissans' : {
        'ticker' : 'RENI',
        'names'  : ['Ренессанс', 'Renessans', 'Ренессанс Групп', 'Renessans Group', 'Renaissance', 'Renaissance Group']
        },
    
    'emc' : {
        'ticker' : 'GEMC',
        'names'  : ['ЕМС', 'EMS', 'ЕМС Групп', 'EMS Group', 'Единая Медицинская Система', 'Unified Medical System']
        },
    'hmsg' : {
        'ticker' : 'HMSG',
        'names'  : ['ГМС Групп', 'GMS Group', 'Группа ГМС', 'ГМС', 'GMS']
        },
    'segezha' : {
        'ticker' : 'SGZH',
        'names'  : ['Segezha', 'Сегежа', 'Группа Сегежа', 'Сегежа Групп', 'Segezha Group', 'сегеж']
        },
    
    'fixprice' : {
        'ticker' : 'FIXP',
        'names'  : ['FixPrice', 'Фикс Прайс', 'Fix-Price', 'Фикспрайс', 'Фикс-Прайс']
        },
    
    'svetofor' : {
        'ticker' : 'SVET',
        'names'  : ['Светофор', 'Svetofor', 'Торговая сеть Светофор', 'Магазин Светофор', 'Дискаунтер Светофор']
        },
    
    'okey' : {
        'ticker' : 'OKEY',
        'names'  : ['ОКЕЙ', "O'KEY", "О'КЕЙ", "О’Кей", 'ОКЕЙ Маркет', 'OKEY']
        },
   
    'ozon' : {
        'ticker' : 'OZON',
        'names'  : ['Озон', 'Ozon', 'Ozon.ru', 'Озон.ру', 'Озон Россия', 'Ozon Russia']
        },
   
    'mtiditya' : {
        'ticker' : 'MDMG',
        'names'  : ['Мать и дитя', 'Mother and Child', 'Мать и Дитя Клиника', 'Mother & Child', 'Медицинский центр Мать и Дитя']
        },
   
    'samolet' : {
        'ticker' : 'SMLT',
        'names'  : ['Самолет', 'Samolyot', 'Самолёт Девелопмент', 'Samolyot Development', 'Группа Самолет', 'Samolyet Group', 'Самолет Групп']
        },
   
    'globaltrans' : {
        'ticker' : 'GLTR',
        'names'  : ['Глобалтранс', 'Globaltrans', 'ГлобалТрансСервис', 'Globaltrans Service', 'Глобал Транс', 'Global Trans']
        },
   
    'sovkomfrot' : {
        'ticker' : 'FLOT',
        'names'  : ['Совкомфлот', 'Sovcomflot', 'ПАО "Совкомфлот"', 'SCF', 'Совкомфлот Групп', 'Sovcomflot Group']
        },
   
    'headhunter' : {
        'ticker' : 'HHRU',
        'names'  : ['Хэдхантер', 'HeadHunter', 'hh.ru', 'HeadHunter Group', 'HH']
        },
   
    'vkontakte' : {
        'ticker' : 'VKCO',
        'names'  : ['ВКонтакте', 'VK', 'VK.com', 'ВК', 'ВКом', 'вКонтакте']
        },
   
    'etalon' : {
        'ticker' : 'ETLN',
        'names'  : ['Эталон', 'Etalon', 'Группа "Эталон"', 'Etalon Group', 'ЭталонГрупп', 'EtalonGroup']
        },
    
    'tcs' : {
        'ticker' : 'TCSG',
        'names'  : ['ТКС', 'TCS', 'Tinkoff Credit Systems', 'Тинькофф', 'Tinkoff', 'Тинькофф Банк', 'Tinkoff Bank']
        },
    
    'gema' : {
        'ticker' : 'GEMA',
        'names'  : ['Гемабанк', 'Совкомбанк', 'Совком', 'Hemabank', 'Sovcombank']
        },
    
    'x5group' : {
        'ticker' : 'FIVE',
        'names'  : ['X5 Group', 'X5 Retail Group', 'X5', 'Пятёрочка', 'Пятерочка', 'Перекрёсток', 'Перекресток', 'Карусель']
        },
    
    'globaltruck' : {
        'ticker' : 'GTRK',
        'names'  : ['Globaltruck', 'Глобалтрак', 'GlobalTruck Management', 'ГлобалТрак Менеджмент']
        },
    
    'euroeltex' : {
        'ticker' : 'EELT',
        'names'  : ['Европейская Электротехника', 'Евроэлтех']
        },
    
    'detsky' : {
        'ticker' : 'DSKY',
        'names'  : ['Детский мир', 'Detsky Mir', 'Детскиймир', 'Кидс Мир', 'Kids World']
        },
    
    'rusneft' : {
        'ticker' : 'RNFT',
        'names'  : ['Руснефть', 'Russneft', 'Rusneft', 'руснефт']
        },
    
    'sfi' : {
        'ticker' : 'SFIN',
        'names'  : ['SFI', 'S.F.I', 'SFI Group', 'SFI Corporation', 'SFI Inc.']
        },
    
    'nkhp' : {
        'ticker' : 'NKHP',
        'names'  : ['НКХП', 'Новороссийский комбинат хлебопродуктов', 'Новороссийск хлебопродукт', 'NKHP']
        },
    
    'mkb' : {
        'ticker' : 'CBOM',
        'names'  : ['МКБ', 'Московский Кредитный Банк', 'MKБ', 'Moscow Credit Bank', 'MKB']
        },
    
    'ovk' : {
        'ticker' : 'UWGN',
        'names'  : ['Whoosh', 'Вуш', 'Whoosh скутершеринг', 'Вуш скутершеринг']
        },
    
    'rosagro' : {
        'ticker' : 'AGRO',
        'names'  : ['Росагро', 'Rosagro', 'Росагропром', 'Российское аграрное объединение', 'Russian Agricultural Group', 'росагр']
        },
    
    'yandex' : {
        'ticker' : 'YNDX',
        'names'  : ['Яндекс', 'Yandex', 'Яндекс Н.В.', 'Yandex N.V.', 'Яндекс Компани', 'Yandex Company']
        }, 
    
    'qiwi' : {
        'ticker' : 'QIWI',
        'names'  : ['QIWI', 'Киви', 'Qiwi Wallet', 'Киви Кошелек']
        },
    
    'polymetal' : {
        'ticker' : 'POLY',
        'names'  : ['Полиметалл', 'Polymetal', 'Полиметалл Интернэшнл', 'Polymetal International']
        },
    
    'moex' : {
        'ticker' : 'MOEX',
        'names'  : ['Мосбиржа', 'Московская Биржа', 'MOEX', 'Moscow Exchange', 'ОАО Московская Биржа', 'мосбирж']
        },
    }

# %%
for key in d:
    if d[key]['ticker'] not in d[key]['names']:
        d[key]['names'].append(d[key]['ticker'])
    cur_list = d[key]['names']
    cur_list = list(map(lambda x: x.lower(), cur_list))
    d[key]['names'] = cur_list

# %%
with open('companies.json', 'w') as f:
    json.dump(d, f)

# %%
import pandas as pd

# %%
data = pd.DataFrame(d).T

# %%
data.head().reset_index()
# Out:
#            index ticker                                              names
# 0        crystal   KLVZ  [кристалл, зао кристалл, пао кристалл, оао кри...
# 1        diasoft   DIAS  [диасофт, diasoft, диасофт финансовые технолог...
# 2      delimobil   DELI  [делимобиль, delimobil, каршеринг делимобиль, ...
# 3  mosgorlombard   MGKL  [мосгорломбард, гуп мосгорломбард, государстве...
# 4     sovkombank   SVCB  [совкомбанк, пао совкомбанк, совкомбанк пао, о...

# %%
quotes = pd.read_csv('../../data/moex/quots_prep.csv', index_col=0)
quotes['ipo_dt'] = pd.to_datetime(quotes['ipo_dt'])
quotes.head()
# Out:
#   ticker        name_ru     ipo_dt  ipo_price  1d_price  1m_price  3m_price  \
# 0   KLVZ       Кристалл 2024-02-22        9.5    -0.147       NaN       NaN
# 1   DIAS        Диасофт 2024-02-13     4500.0     0.400       NaN       NaN
# 2   DELI     Делимобиль 2024-06-02      265.0     0.068      0.08       NaN
# 3   MGKL  Мосгорломбард 2023-12-28        2.5    -0.052     -0.01       NaN
# 4   SVCB     Совкомбанк 2023-12-15       11.5     0.087      0.20       NaN
#
#    6m_price
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
pd.merge(quotes[])
